# %%
import matplotlib.pyplot as plt
import numpy as np

# Define M values (e.g., from 1 to 8)
M_values = np.arange(1, 11)

# Simulated accuracy values for different N configurations
accuracy_N1 = np.array([
    0.919,
    0.927,
    0.922,
    0.927,
    0.933,
    0.933,
    0.924,
    0.927,
    0.927,
    0.926,
])
accuracy_N2 = np.array([
    0.928,
    0.926,
    0.923,
    0.923,
    0.931,
    0.927,
    0.927,
    0.926,
    0.921,
    0.923,
])
accuracy_N3 = np.array([
    0.926,
    0.922,
    0.924,
    0.924,
    0.925,
    0.919,
    0.926,
    0.921,
    0.922,
    0.922,
])

# Plot the accuracy trends
plt.figure(figsize=(8, 5), dpi=200)
plt.plot(M_values, accuracy_N1, marker='o', linestyle='-', label='$N=1$')
plt.plot(M_values, accuracy_N2, marker='s', linestyle='--', label='$N=2$')
plt.plot(M_values, accuracy_N3, marker='^', linestyle='-.', label='$N=3$')

# Labels and title
plt.xlabel('Temporal Modeling Capacity ($M$)')
plt.ylabel('Accuracy')
# plt.title('Impact of M on Accuracy for Different N Values')
plt.xticks(M_values)
plt.ylim(0.91, 0.94)
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define M values (e.g., from 1 to 8)
M_values = np.arange(1, 11)

# Simulated accuracy values for different N configurations
accuracy_N1 = np.array([
    0.894,
    0.904,
    0.899,
    0.907,
    0.910,
    0.912,
    0.902,
    0.905,
    0.905,
    0.902,

])
accuracy_N2 = np.array([
    0.904,
    0.904,
    0.900,
    0.897,
    0.911,
    0.907,
    0.908,
    0.905,
    0.898,
    0.903,
])
accuracy_N3 = np.array([
    0.903,
    0.894,
    0.902,
    0.900,
    0.900,
    0.893,
    0.903,
    0.898,
    0.895,
    0.900,
])

# Plot the accuracy trends
plt.figure(figsize=(8, 5))
plt.plot(M_values, accuracy_N1, marker='o', linestyle='-', label='N=1')
plt.plot(M_values, accuracy_N2, marker='s', linestyle='--', label='N=2')
plt.plot(M_values, accuracy_N3, marker='^', linestyle='-.', label='N=3')

# Labels and title
plt.xlabel('M (Temporal Modeling Capacity)')
plt.ylabel('Accuracy')
plt.title('Impact of M on Accuracy for Different N Values')
plt.xticks(M_values)
plt.ylim(0.86, 0.92)
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(dpi=200)
labels = ["Normal", "Apnea"]
# get the matrix as counts and percents
count = np.array([
    [10099, 602],
    [549, 5998]
])
per = count / count.sum(axis=1, keepdims=True)

# create dataframe
cm = pd.DataFrame(per, index=labels, columns=labels)
cm.index.name = 'True Labels'
cm.columns.name = 'Predicted Labels'

# plot
annot = np.asarray([f"{v1:,d}\n({v2:.0%})" for v1, v2 in zip(count.ravel(), per.ravel())])
annot = annot.reshape((len(labels), len(labels)))

sns.set(font_scale=1.)
sns.heatmap(cm, annot=annot, cbar=False, fmt='', cmap="Blues", linewidths=0.1, square=True, vmin=0, vmax=1,
            linecolor="Black")
plt.ylabel('True Labels', weight="bold")
plt.xlabel('Predicted Labels', weight="bold")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(dpi=200)
labels = ["Normal", "Apnea"]
# get the matrix as counts and percents
count = np.array([
    [12, 0],
    [0, 23]
])
per = count / count.sum(axis=1, keepdims=True)

# create dataframe
cm = pd.DataFrame(per, index=labels, columns=labels)
cm.index.name = 'True Labels'
cm.columns.name = 'Predicted Labels'

# plot
annot = np.asarray([f"{v1:,d}\n({v2:.0%})" for v1, v2 in zip(count.ravel(), per.ravel())])
annot = annot.reshape((len(labels), len(labels)))

sns.set(font_scale=1.)
sns.heatmap(cm, annot=annot, cbar=False, fmt='', cmap="Blues", linewidths=0.1, square=True, vmin=0, vmax=1,
            linecolor="Black")
plt.ylabel('True Labels', weight="bold")
plt.xlabel('Predicted Labels', weight="bold")
plt.show()
